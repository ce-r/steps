# %%
import pandas as pd
import numpy as np

# %%
disease = pd.read_csv('infectious_diseases.csv')

# %%
disease.head()
# Out:
#      Disease       County  Year     Sex  Count  Population   Rate  CI. lower  \
# 0  Amebiasis       Solano  2005   Total      0      410570  0.000      0.000
# 1  Amebiasis        Marin  2005    Male      4      121710  3.287      0.895
# 2  Amebiasis         Kern  2010  Female      1      404863  0.247      0.006
# 3  Amebiasis       Tulare  2001  Female      1      186935  0.535      0.014
# 4  Amebiasis  Los Angeles  2014  Female     17     5127242  0.332      0.193
#
#    CI.upper Unstable
# 0     0.898        -
# 1     8.415        *
# 2     1.376        *
# 3     2.980        *
# 4     0.531        *

# %%
disease.Year.isnull().sum()
# Out:
# 0

# %%
disease['Year'] = disease['Year'].astype(int)
# disease['Year'] = pd.to_numeric(disease['Year'], errors='coerce')
# disease['Year'].fillna(0).astype(int)
disease['Year'].head()
# Out:
# 0    2005
# 1    2005
# 2    2010
# 3    2001
# 4    2014
# Name: Year, dtype: int32

# %%
disease['County'].unique()
# Out:
# array(['Solano', 'Marin', 'Kern', 'Tulare', 'Los Angeles', 'Napa',
#        'Mariposa', 'Shasta', 'Sutter', 'Lake', 'Ventura', 'Sierra',
#        'Mono', 'Madera', 'Santa Barbara', 'Inyo', 'Sonoma',
#        'San Bernardino', 'Kings', 'Tehama', 'Tuolumne', 'Yuba',
#        'San Mateo', 'Monterey', 'San Benito', 'Nevada', 'Santa Clara',
#        'Merced', 'Plumas', 'Stanislaus', 'Trinity', 'San Francisco',
#        'Yolo', 'Lassen', 'Mendocino', 'Sacramento', 'Placer',
#        'Santa Cruz', 'Orange', 'San Diego', 'Riverside', 'Modoc',
#        'Siskiyou', 'San Luis Obispo', 'Imperial', 'Humboldt',
#        'San Joaquin', 'Alpine', 'Alameda', 'Amador', 'Contra Costa',
#        'California', 'Calaveras', 'Glenn', 'Butte', 'El Dorado', 'Fresno',
#        'Del Norte', 'Colusa'], dtype=object)

# %%
disease['County'].nunique()
# Out:
# 59

# %%
# disease[disease['County'].str.contains('Chambers')]
disease.sort_values('County').head()
# Out:
#                                                   Disease   County  Year  \
# 103455  Shiga Toxin Positive Feces (without culture co...  Alameda  2015
# 89171                                         Psittacosis  Alameda  2004
# 109309                        Spotted Fever Rickettsiosis  Alameda  2005
# 37862                          Cysticercosis or Taeniasis  Alameda  2005
# 32245   Creutzfeldt-Jakob Disease and other Transmissi...  Alameda  2009
#
#            Sex  Count  Population   Rate  CI. lower  CI.upper Unstable
# 103455   Total      2     1619679  0.123      0.015     0.446        *
# 89171   Female      0      746723  0.000      0.000     0.494        -
# 109309   Total      0     1459882  0.000      0.000     0.253        -
# 37862     Male      2      716004  0.279      0.034     1.009        *
# 32245    Total      1     1503827  0.066      0.002     0.370        *

# %%
disease['County'] = disease['County'].str.strip(' ')
disease.head()
# Out:
#      Disease       County  Year     Sex  Count  Population   Rate  CI. lower  \
# 0  Amebiasis       Solano  2005   Total      0      410570  0.000      0.000
# 1  Amebiasis        Marin  2005    Male      4      121710  3.287      0.895
# 2  Amebiasis         Kern  2010  Female      1      404863  0.247      0.006
# 3  Amebiasis       Tulare  2001  Female      1      186935  0.535      0.014
# 4  Amebiasis  Los Angeles  2014  Female     17     5127242  0.332      0.193
#
#    CI.upper Unstable
# 0     0.898        -
# 1     8.415        *
# 2     1.376        *
# 3     2.980        *
# 4     0.531        *

# %%
disease['County'].unique()
# Out:
# array(['Solano', 'Marin', 'Kern', 'Tulare', 'Los Angeles', 'Napa',
#        'Mariposa', 'Shasta', 'Sutter', 'Lake', 'Ventura', 'Sierra',
#        'Mono', 'Madera', 'Santa Barbara', 'Inyo', 'Sonoma',
#        'San Bernardino', 'Kings', 'Tehama', 'Tuolumne', 'Yuba',
#        'San Mateo', 'Monterey', 'San Benito', 'Nevada', 'Santa Clara',
#        'Merced', 'Plumas', 'Stanislaus', 'Trinity', 'San Francisco',
#        'Yolo', 'Lassen', 'Mendocino', 'Sacramento', 'Placer',
#        'Santa Cruz', 'Orange', 'San Diego', 'Riverside', 'Modoc',
#        'Siskiyou', 'San Luis Obispo', 'Imperial', 'Humboldt',
#        'San Joaquin', 'Alpine', 'Alameda', 'Amador', 'Contra Costa',
#        'California', 'Calaveras', 'Glenn', 'Butte', 'El Dorado', 'Fresno',
#        'Del Norte', 'Colusa'], dtype=object)

# %%
gdp = pd.read_excel('gdp.xlsx',sheet_name='Real GDP')
# gdp data is all real gdp

# %%
gdp.rename(columns={"Countyname":"County", "Real Gross domestic product (GDP) by county":"2012", "Unnamed: 6":"2013", "Unnamed: 7":"2014", "Unnamed: 8":"2015"}, inplace=True)
gdp1 = gdp.loc[2:,:]
gdp1.head()
# Out:
#     FIPS   County Postal  LineCode                             IndustryName  \
# 2  01001  Autauga     AL       1.0                           All Industries
# 3  01001  Autauga     AL       2.0       Private goods-producing industries
# 4  01001  Autauga     AL       3.0    Private services-providing industries
# 5  01001  Autauga     AL       4.0    Government and government enterprises
# 6  01003  Baldwin     AL       1.0                           All Industries
#
#       2012     2013     2014     2015
# 2  1383941  1322416  1312668  1412939
# 3   286396   299115   310672   325250
# 4   948490   880098   861153   946148
# 5   149055   143062   140893   141294
# 6  5599194  6218819  6247887  5981958

# %%
gdp_l = gdp1[gdp1['LineCode']==1.0]
#gdp_last = pd.melt(gdp_last, id_vars='County')
gdp_l.drop(['FIPS','LineCode','IndustryName'],axis=1,inplace=True)
# drop ,'IndustryName','Postal' 
# removed: inplace=True
gdp_l.head()
# Out:
#      County Postal     2012     2013     2014     2015
# 2   Autauga     AL  1383941  1322416  1312668  1412939
# 6   Baldwin     AL  5599194  6218819  6247887  5981958
# 10  Barbour     AL   639833   687532   663462   708778
# 14     Bibb     AL   297560   314380   305472   291780
# 18   Blount     AL   632761   683949   661352   778131

# %%
gdp_last = pd.melt(gdp_l,id_vars=['County','Postal'], var_name='Year', value_name='GDP')
gdp_last.head()
# Out:
#     County Postal  Year      GDP
# 0  Autauga     AL  2012  1383941
# 1  Baldwin     AL  2012  5599194
# 2  Barbour     AL  2012   639833
# 3     Bibb     AL  2012   297560
# 4   Blount     AL  2012   632761

# %%
gdp_last[gdp_last['County']=='Baldwin'].head()
# Out:
#        County Postal  Year      GDP
# 1     Baldwin     AL  2012  5599194
# 391   Baldwin     GA  2012  1106089
# 3114  Baldwin     AL  2013  6218819
# 3504  Baldwin     GA  2013  1053999
# 6227  Baldwin     AL  2014  6247887

# %%
gdp_last['County'] = gdp_last['County'].str.strip(' ')
gdp_last.head()
# Out:
#     County Postal  Year      GDP
# 0  Autauga     AL  2012  1383941
# 1  Baldwin     AL  2012  5599194
# 2  Barbour     AL  2012   639833
# 3     Bibb     AL  2012   297560
# 4   Blount     AL  2012   632761

# %%
gdp_last.Year.isnull().sum()
# Out:
# 0

# %%
gdp_last['Year'] = gdp_last['Year'].astype(int)
# gdp_ca['Year'] = pd.to_numeric(gdp_ca['Year'], errors='coerce')
gdp_last['Year'].head()
# Out:
# 0    2012
# 1    2012
# 2    2012
# 3    2012
# 4    2012
# Name: Year, dtype: int32

# %%
gdp_ca = gdp_last[gdp_last['Postal']=='CA']
gdp_ca.head()
# Out:
#         County Postal  Year       GDP
# 186    Alameda     CA  2012  93795276
# 187     Alpine     CA  2012     91253
# 188     Amador     CA  2012   1106242
# 189      Butte     CA  2012   6399648
# 190  Calaveras     CA  2012    771457

# %%
gdp_ca['County'].unique()
# Out:
# array(['Alameda', 'Alpine', 'Amador', 'Butte', 'Calaveras', 'Colusa',
#        'Contra Costa', 'Del Norte', 'El Dorado', 'Fresno', 'Glenn',
#        'Humboldt', 'Imperial', 'Inyo', 'Kern', 'Kings', 'Lake', 'Lassen',
#        'Los Angeles', 'Madera', 'Marin', 'Mariposa', 'Mendocino',
#        'Merced', 'Modoc', 'Mono', 'Monterey', 'Napa', 'Nevada', 'Orange',
#        'Placer', 'Plumas', 'Riverside', 'Sacramento', 'San Benito',
#        'San Bernardino', 'San Diego', 'San Francisco', 'San Joaquin',
#        'San Luis Obispo', 'San Mateo', 'Santa Barbara', 'Santa Clara',
#        'Santa Cruz', 'Shasta', 'Sierra', 'Siskiyou', 'Solano', 'Sonoma',
#        'Stanislaus', 'Sutter', 'Tehama', 'Trinity', 'Tulare', 'Tuolumne',
#        'Ventura', 'Yolo', 'Yuba'], dtype=object)

# %%
gdp_ca['County'].nunique()
# Out:
# 58

# %%
# gdpca = gdp_last.drop('Postal',axis=1,inplace=True)
gdpca = gdp_last.drop('Postal',axis=1)

# %%
gdpca.head()
# WINNER!!!!!!!!!!
# i didn't drop anything and yet it shows that i did
# Out:
#     County  Year      GDP
# 0  Autauga  2012  1383941
# 1  Baldwin  2012  5599194
# 2  Barbour  2012   639833
# 3     Bibb  2012   297560
# 4   Blount  2012   632761

# %%
grow = pd.read_excel('gdp.xlsx',sheet_name='Real GDP Growth')

# %%
grow.rename(columns={"Countyname":"County","Real Gross domestic product (GDP) by county growth":"2013", "Unnamed: 6":"2014", "Unnamed: 7":"2015"}, inplace=True)
growth = grow.loc[2:,:]
#growth.head()
#growth[growth['Postal']=='LA'].iloc[250:300,:4]
#growth[growth['Postal']=='AK']
#.iloc[100:150,:4]
#growth[growth['Postal']=='AL']
# keep 'All Industries'
#growth1 = growth[growth['LineCode']==1.0]
#growth1[growth1['County']=='Baldwin']

# %%
growth_l = growth[growth['LineCode']==1.0]
growth_l.drop(['FIPS','LineCode','IndustryName'],axis=1,inplace=True)
# drop ,'Postal'
growth_l.head()
# Out:
#      County Postal  2013 2014  2015
# 2   Autauga     AL  -4.4 -0.7   7.6
# 6   Baldwin     AL  11.1  0.5  -4.3
# 10  Barbour     AL   7.5 -3.5   6.8
# 14     Bibb     AL   5.7 -2.8  -4.5
# 18   Blount     AL   8.1 -3.3  17.7

# %%
growth_ca = pd.melt(growth_l,id_vars=['County','Postal'],var_name='Year',value_name='GDPgrowth')
growth_ca.head()
# Out:
#     County Postal  Year GDPgrowth
# 0  Autauga     AL  2013      -4.4
# 1  Baldwin     AL  2013      11.1
# 2  Barbour     AL  2013       7.5
# 3     Bibb     AL  2013       5.7
# 4   Blount     AL  2013       8.1

# %%
#growca = growth.drop('Postal',axis=1)
#growca

# %%
groca = growth_ca[growth_ca['Postal']=='CA']
groca.head()
# Out:
#         County Postal  Year GDPgrowth
# 186    Alameda     CA  2013       4.1
# 187     Alpine     CA  2013     -11.8
# 188     Amador     CA  2013       4.5
# 189      Butte     CA  2013       3.9
# 190  Calaveras     CA  2013       1.9

# %%
# groca['County'] = groca['County'].str.strip(' ')
#groca['County'] = groca['County'].str.strip(' ')
groca['County'].str.strip(' ')
groca.head()
# Out:
#         County Postal  Year GDPgrowth
# 186    Alameda     CA  2013       4.1
# 187     Alpine     CA  2013     -11.8
# 188     Amador     CA  2013       4.5
# 189      Butte     CA  2013       3.9
# 190  Calaveras     CA  2013       1.9

# %%
# groca['Year'].astype(int).head()
groca['Year'] = groca['Year'].astype(int)
groca['Year'].head()
# groca['Year'] = pd.to_numeric(groca['Year'], errors='coerce')
# Out:
# C:\Users\aufst\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# 186    2013
# 187    2013
# 188    2013
# 189    2013
# 190    2013
# Name: Year, dtype: int32

# %%
groca['County'].unique()
# Out:
# array(['Alameda', 'Alpine', 'Amador', 'Butte', 'Calaveras', 'Colusa',
#        'Contra Costa', 'Del Norte', 'El Dorado', 'Fresno', 'Glenn',
#        'Humboldt', 'Imperial', 'Inyo', 'Kern', 'Kings', 'Lake', 'Lassen',
#        'Los Angeles', 'Madera', 'Marin', 'Mariposa', 'Mendocino',
#        'Merced', 'Modoc', 'Mono', 'Monterey', 'Napa', 'Nevada', 'Orange',
#        'Placer', 'Plumas', 'Riverside', 'Sacramento', 'San Benito',
#        'San Bernardino', 'San Diego', 'San Francisco', 'San Joaquin',
#        'San Luis Obispo', 'San Mateo', 'Santa Barbara', 'Santa Clara',
#        'Santa Cruz', 'Shasta', 'Sierra', 'Siskiyou', 'Solano', 'Sonoma',
#        'Stanislaus', 'Sutter', 'Tehama', 'Trinity', 'Tulare', 'Tuolumne',
#        'Ventura', 'Yolo', 'Yuba'], dtype=object)

# %%
groca['County'].nunique()
# Out:
# 58

# %%
growthca = groca.drop('Postal',axis=1)
growthca.head()
# WINNER!!!!!!!!!!!!!!!
# Out:
#         County  Year GDPgrowth
# 186    Alameda  2013       4.1
# 187     Alpine  2013     -11.8
# 188     Amador  2013       4.5
# 189      Butte  2013       3.9
# 190  Calaveras  2013       1.9

# %%
unemp = pd.read_excel('unemployment.xls',sheet_name='Unemployment Med HH Inc',skiprows=range(0,7))

# %%
unemp.rename(columns={"Area_name":"County"}, inplace=True)
#unemp.head()
unemp.iloc[69:102,:4].head()
# Out:
#     FIPStxt State                              County  \
# 69     2000    AK                              Alaska
# 70     2013    AK          Aleutians East Borough, AK
# 71     2016    AK      Aleutians West Census Area, AK
# 72     2020    AK  Anchorage Borough/municipality, AK
# 73     2050    AK              Bethel Census Area, AK
#
#     Rural_urban_continuum_code_2013
# 69                              NaN
# 70                              9.0
# 71                              9.0
# 72                              2.0
# 73                              7.0

# %%
unemp[unemp['County'].str.contains(',')].head()
# Out:
#    FIPStxt State              County  Rural_urban_continuum_code_2013  \
# 2     1001    AL  Autauga County, AL                              2.0
# 3     1003    AL  Baldwin County, AL                              3.0
# 4     1005    AL  Barbour County, AL                              6.0
# 5     1007    AL     Bibb County, AL                              1.0
# 6     1009    AL   Blount County, AL                              1.0
#
#    Urban_influence_code_2013  Metro_2013  Civilian_labor_force_2007  \
# 2                        2.0         1.0                    24383.0
# 3                        2.0         1.0                    82659.0
# 4                        6.0         0.0                    10334.0
# 5                        1.0         1.0                     8791.0
# 6                        1.0         1.0                    26629.0
#
#    Employed_2007  Unemployed_2007  Unemployment_rate_2007  \
# 2        23577.0            806.0                     3.3
# 3        80099.0           2560.0                     3.1
# 4         9684.0            650.0                     6.3
# 5         8432.0            359.0                     4.1
# 6        25780.0            849.0                     3.2
#
#                      ...                      Civilian_labor_force_2016  \
# 2                    ...                                        25918.0
# 3                    ...                                        90500.0
# 4                    ...                                         8402.0
# 5                    ...                                         8607.0
# 6                    ...                                        24576.0
#
#    Employed_2016  Unemployed_2016  Unemployment_rate_2016  \
# 2        24593.0           1325.0                     5.1
# 3        85656.0           4844.0                     5.4
# 4         7700.0            702.0                     8.4
# 5         8050.0            557.0                     6.5
# 6        23248.0           1328.0                     5.4
#
#    Civilian_labor_force_2017  Employed_2017  Unemployed_2017  \
# 2                    25909.0        24908.0           1001.0
# 3                    91567.0        87915.0           3652.0
# 4                     8236.0         7750.0            486.0
# 5                     8506.0         8133.0            373.0
# 6                    24494.0        23509.0            985.0
#
#    Unemployment_rate_2017  Median_Household_Income_2017  \
# 2                     3.9                       58343.0
# 3                     4.0                       56607.0
# 4                     5.9                       32490.0
# 5                     4.4                       45795.0
# 6                     4.0                       48253.0
#
#    Med_HH_Income_Percent_of_State_Total_2017
# 2                                      121.1
# 3                                      117.5
# 4                                       67.4
# 5                                       95.0
# 6                                      100.1
#
# [5 rows x 52 columns]

# %%
unemp[unemp['County'].str.contains('/')].head()
# Out:
#      FIPStxt State                              County  \
# 72      2020    AK  Anchorage Borough/municipality, AK
# 80      2110    AK             Juneau Borough/city, AK
# 93      2220    AK              Sitka Borough/city, AK
# 98      2275    AK           Wrangell Borough/city, AK
# 100     2282    AK            Yakutat Borough/city, AK
#
#      Rural_urban_continuum_code_2013  Urban_influence_code_2013  Metro_2013  \
# 72                               2.0                        2.0         1.0
# 80                               5.0                        8.0         0.0
# 93                               7.0                       11.0         0.0
# 98                               9.0                       12.0         0.0
# 100                              9.0                       12.0         0.0
#
#      Civilian_labor_force_2007  Employed_2007  Unemployed_2007  \
# 72                    151051.0       143336.0           7715.0
# 80                     18459.0        17626.0            833.0
# 93                      4635.0         4398.0            237.0
# 98                         NaN            NaN              NaN
# 100                      308.0          287.0             21.0
#
#      Unemployment_rate_2007                    ...                      \
# 72                      5.1                    ...
# 80                      4.5                    ...
# 93                      5.1                    ...
# 98                      NaN                    ...
# 100                     6.8                    ...
#
#      Civilian_labor_force_2016  Employed_2016  Unemployed_2016  \
# 72                    155798.0       147142.0           8656.0
# 80                     17372.0        16587.0            785.0
# 93                      4380.0         4176.0            204.0
# 98                      1056.0          976.0             80.0
# 100                      245.0          224.0             21.0
#
#      Unemployment_rate_2016  Civilian_labor_force_2017  Employed_2017  \
# 72                      5.6                   155462.0       146175.0
# 80                      4.5                    17435.0        16607.0
# 93                      4.7                     4449.0         4241.0
# 98                      7.6                     1050.0          969.0
# 100                     8.6                      235.0          213.0
#
#      Unemployed_2017  Unemployment_rate_2017  Median_Household_Income_2017  \
# 72            9287.0                     6.0                       78579.0
# 80             828.0                     4.7                       90436.0
# 93             208.0                     4.7                       69501.0
# 98              81.0                     7.7                       55696.0
# 100             22.0                     9.4                       59955.0
#
#      Med_HH_Income_Percent_of_State_Total_2017
# 72                                       106.1
# 80                                       122.1
# 93                                        93.8
# 98                                        75.2
# 100                                       81.0
#
# [5 rows x 52 columns]

# %%
unemp[unemp['County'].str.contains('County')].head()
# Out:
#    FIPStxt State              County  Rural_urban_continuum_code_2013  \
# 2     1001    AL  Autauga County, AL                              2.0
# 3     1003    AL  Baldwin County, AL                              3.0
# 4     1005    AL  Barbour County, AL                              6.0
# 5     1007    AL     Bibb County, AL                              1.0
# 6     1009    AL   Blount County, AL                              1.0
#
#    Urban_influence_code_2013  Metro_2013  Civilian_labor_force_2007  \
# 2                        2.0         1.0                    24383.0
# 3                        2.0         1.0                    82659.0
# 4                        6.0         0.0                    10334.0
# 5                        1.0         1.0                     8791.0
# 6                        1.0         1.0                    26629.0
#
#    Employed_2007  Unemployed_2007  Unemployment_rate_2007  \
# 2        23577.0            806.0                     3.3
# 3        80099.0           2560.0                     3.1
# 4         9684.0            650.0                     6.3
# 5         8432.0            359.0                     4.1
# 6        25780.0            849.0                     3.2
#
#                      ...                      Civilian_labor_force_2016  \
# 2                    ...                                        25918.0
# 3                    ...                                        90500.0
# 4                    ...                                         8402.0
# 5                    ...                                         8607.0
# 6                    ...                                        24576.0
#
#    Employed_2016  Unemployed_2016  Unemployment_rate_2016  \
# 2        24593.0           1325.0                     5.1
# 3        85656.0           4844.0                     5.4
# 4         7700.0            702.0                     8.4
# 5         8050.0            557.0                     6.5
# 6        23248.0           1328.0                     5.4
#
#    Civilian_labor_force_2017  Employed_2017  Unemployed_2017  \
# 2                    25909.0        24908.0           1001.0
# 3                    91567.0        87915.0           3652.0
# 4                     8236.0         7750.0            486.0
# 5                     8506.0         8133.0            373.0
# 6                    24494.0        23509.0            985.0
#
#    Unemployment_rate_2017  Median_Household_Income_2017  \
# 2                     3.9                       58343.0
# 3                     4.0                       56607.0
# 4                     5.9                       32490.0
# 5                     4.4                       45795.0
# 6                     4.0                       48253.0
#
#    Med_HH_Income_Percent_of_State_Total_2017
# 2                                      121.1
# 3                                      117.5
# 4                                       67.4
# 5                                       95.0
# 6                                      100.1
#
# [5 rows x 52 columns]

# %%
unemp['County'] = unemp['County'].apply(lambda x:x.split(',')[0])
unemp.head()
# Out:
#    FIPStxt State          County  Rural_urban_continuum_code_2013  \
# 0        0    US   United States                              NaN
# 1     1000    AL         Alabama                              NaN
# 2     1001    AL  Autauga County                              2.0
# 3     1003    AL  Baldwin County                              3.0
# 4     1005    AL  Barbour County                              6.0
#
#    Urban_influence_code_2013  Metro_2013  Civilian_labor_force_2007  \
# 0                        NaN         NaN                152191093.0
# 1                        NaN         NaN                  2175612.0
# 2                        2.0         1.0                    24383.0
# 3                        2.0         1.0                    82659.0
# 4                        6.0         0.0                    10334.0
#
#    Employed_2007  Unemployed_2007  Unemployment_rate_2007  \
# 0    145156134.0        7034959.0                     4.6
# 1      2089127.0          86485.0                     4.0
# 2        23577.0            806.0                     3.3
# 3        80099.0           2560.0                     3.1
# 4         9684.0            650.0                     6.3
#
#                      ...                      Civilian_labor_force_2016  \
# 0                    ...                                    158921892.0
# 1                    ...                                      2173175.0
# 2                    ...                                        25918.0
# 3                    ...                                        90500.0
# 4                    ...                                         8402.0
#
#    Employed_2016  Unemployed_2016  Unemployment_rate_2016  \
# 0    151183680.0        7738212.0                     4.9
# 1      2045624.0         127551.0                     5.9
# 2        24593.0           1325.0                     5.1
# 3        85656.0           4844.0                     5.4
# 4         7700.0            702.0                     8.4
#
#    Civilian_labor_force_2017  Employed_2017  Unemployed_2017  \
# 0                160588515.0    153594100.0        6994415.0
# 1                  2168444.0      2073106.0          95338.0
# 2                    25909.0        24908.0           1001.0
# 3                    91567.0        87915.0           3652.0
# 4                     8236.0         7750.0            486.0
#
#    Unemployment_rate_2017  Median_Household_Income_2017  \
# 0                     4.4                       60336.0
# 1                     4.4                       48193.0
# 2                     3.9                       58343.0
# 3                     4.0                       56607.0
# 4                     5.9                       32490.0
#
#    Med_HH_Income_Percent_of_State_Total_2017
# 0                                        NaN
# 1                                      100.0
# 2                                      121.1
# 3                                      117.5
# 4                                       67.4
#
# [5 rows x 52 columns]

# %%
unemp.iloc[:,:10].head()
# Out:
#    FIPStxt State          County  Rural_urban_continuum_code_2013  \
# 0        0    US   United States                              NaN
# 1     1000    AL         Alabama                              NaN
# 2     1001    AL  Autauga County                              2.0
# 3     1003    AL  Baldwin County                              3.0
# 4     1005    AL  Barbour County                              6.0
#
#    Urban_influence_code_2013  Metro_2013  Civilian_labor_force_2007  \
# 0                        NaN         NaN                152191093.0
# 1                        NaN         NaN                  2175612.0
# 2                        2.0         1.0                    24383.0
# 3                        2.0         1.0                    82659.0
# 4                        6.0         0.0                    10334.0
#
#    Employed_2007  Unemployed_2007  Unemployment_rate_2007
# 0    145156134.0        7034959.0                     4.6
# 1      2089127.0          86485.0                     4.0
# 2        23577.0            806.0                     3.3
# 3        80099.0           2560.0                     3.1
# 4         9684.0            650.0                     6.3

# %%
unemp['County'] = unemp['County'].apply(lambda x:x.split('County')[0])
unemp.head()
# Out:
#    FIPStxt State         County  Rural_urban_continuum_code_2013  \
# 0        0    US  United States                              NaN
# 1     1000    AL        Alabama                              NaN
# 2     1001    AL       Autauga                               2.0
# 3     1003    AL       Baldwin                               3.0
# 4     1005    AL       Barbour                               6.0
#
#    Urban_influence_code_2013  Metro_2013  Civilian_labor_force_2007  \
# 0                        NaN         NaN                152191093.0
# 1                        NaN         NaN                  2175612.0
# 2                        2.0         1.0                    24383.0
# 3                        2.0         1.0                    82659.0
# 4                        6.0         0.0                    10334.0
#
#    Employed_2007  Unemployed_2007  Unemployment_rate_2007  \
# 0    145156134.0        7034959.0                     4.6
# 1      2089127.0          86485.0                     4.0
# 2        23577.0            806.0                     3.3
# 3        80099.0           2560.0                     3.1
# 4         9684.0            650.0                     6.3
#
#                      ...                      Civilian_labor_force_2016  \
# 0                    ...                                    158921892.0
# 1                    ...                                      2173175.0
# 2                    ...                                        25918.0
# 3                    ...                                        90500.0
# 4                    ...                                         8402.0
#
#    Employed_2016  Unemployed_2016  Unemployment_rate_2016  \
# 0    151183680.0        7738212.0                     4.9
# 1      2045624.0         127551.0                     5.9
# 2        24593.0           1325.0                     5.1
# 3        85656.0           4844.0                     5.4
# 4         7700.0            702.0                     8.4
#
#    Civilian_labor_force_2017  Employed_2017  Unemployed_2017  \
# 0                160588515.0    153594100.0        6994415.0
# 1                  2168444.0      2073106.0          95338.0
# 2                    25909.0        24908.0           1001.0
# 3                    91567.0        87915.0           3652.0
# 4                     8236.0         7750.0            486.0
#
#    Unemployment_rate_2017  Median_Household_Income_2017  \
# 0                     4.4                       60336.0
# 1                     4.4                       48193.0
# 2                     3.9                       58343.0
# 3                     4.0                       56607.0
# 4                     5.9                       32490.0
#
#    Med_HH_Income_Percent_of_State_Total_2017
# 0                                        NaN
# 1                                      100.0
# 2                                      121.1
# 3                                      117.5
# 4                                       67.4
#
# [5 rows x 52 columns]

# %%
unemp[unemp['State'] != 'PR'].head()
# Out:
#    FIPStxt State         County  Rural_urban_continuum_code_2013  \
# 0        0    US  United States                              NaN
# 1     1000    AL        Alabama                              NaN
# 2     1001    AL       Autauga                               2.0
# 3     1003    AL       Baldwin                               3.0
# 4     1005    AL       Barbour                               6.0
#
#    Urban_influence_code_2013  Metro_2013  Civilian_labor_force_2007  \
# 0                        NaN         NaN                152191093.0
# 1                        NaN         NaN                  2175612.0
# 2                        2.0         1.0                    24383.0
# 3                        2.0         1.0                    82659.0
# 4                        6.0         0.0                    10334.0
#
#    Employed_2007  Unemployed_2007  Unemployment_rate_2007  \
# 0    145156134.0        7034959.0                     4.6
# 1      2089127.0          86485.0                     4.0
# 2        23577.0            806.0                     3.3
# 3        80099.0           2560.0                     3.1
# 4         9684.0            650.0                     6.3
#
#                      ...                      Civilian_labor_force_2016  \
# 0                    ...                                    158921892.0
# 1                    ...                                      2173175.0
# 2                    ...                                        25918.0
# 3                    ...                                        90500.0
# 4                    ...                                         8402.0
#
#    Employed_2016  Unemployed_2016  Unemployment_rate_2016  \
# 0    151183680.0        7738212.0                     4.9
# 1      2045624.0         127551.0                     5.9
# 2        24593.0           1325.0                     5.1
# 3        85656.0           4844.0                     5.4
# 4         7700.0            702.0                     8.4
#
#    Civilian_labor_force_2017  Employed_2017  Unemployed_2017  \
# 0                160588515.0    153594100.0        6994415.0
# 1                  2168444.0      2073106.0          95338.0
# 2                    25909.0        24908.0           1001.0
# 3                    91567.0        87915.0           3652.0
# 4                     8236.0         7750.0            486.0
#
#    Unemployment_rate_2017  Median_Household_Income_2017  \
# 0                     4.4                       60336.0
# 1                     4.4                       48193.0
# 2                     3.9                       58343.0
# 3                     4.0                       56607.0
# 4                     5.9                       32490.0
#
#    Med_HH_Income_Percent_of_State_Total_2017
# 0                                        NaN
# 1                                      100.0
# 2                                      121.1
# 3                                      117.5
# 4                                       67.4
#
# [5 rows x 52 columns]

# %%
#unemp[unemp['County'].str.contains('/')]
unemp['County'] = unemp['County'].apply(lambda x:x.split('/')[0])
unemp_l = unemp.loc[2:,:]
unemp_l.head()
# Out:
#    FIPStxt State    County  Rural_urban_continuum_code_2013  \
# 2     1001    AL  Autauga                               2.0
# 3     1003    AL  Baldwin                               3.0
# 4     1005    AL  Barbour                               6.0
# 5     1007    AL     Bibb                               1.0
# 6     1009    AL   Blount                               1.0
#
#    Urban_influence_code_2013  Metro_2013  Civilian_labor_force_2007  \
# 2                        2.0         1.0                    24383.0
# 3                        2.0         1.0                    82659.0
# 4                        6.0         0.0                    10334.0
# 5                        1.0         1.0                     8791.0
# 6                        1.0         1.0                    26629.0
#
#    Employed_2007  Unemployed_2007  Unemployment_rate_2007  \
# 2        23577.0            806.0                     3.3
# 3        80099.0           2560.0                     3.1
# 4         9684.0            650.0                     6.3
# 5         8432.0            359.0                     4.1
# 6        25780.0            849.0                     3.2
#
#                      ...                      Civilian_labor_force_2016  \
# 2                    ...                                        25918.0
# 3                    ...                                        90500.0
# 4                    ...                                         8402.0
# 5                    ...                                         8607.0
# 6                    ...                                        24576.0
#
#    Employed_2016  Unemployed_2016  Unemployment_rate_2016  \
# 2        24593.0           1325.0                     5.1
# 3        85656.0           4844.0                     5.4
# 4         7700.0            702.0                     8.4
# 5         8050.0            557.0                     6.5
# 6        23248.0           1328.0                     5.4
#
#    Civilian_labor_force_2017  Employed_2017  Unemployed_2017  \
# 2                    25909.0        24908.0           1001.0
# 3                    91567.0        87915.0           3652.0
# 4                     8236.0         7750.0            486.0
# 5                     8506.0         8133.0            373.0
# 6                    24494.0        23509.0            985.0
#
#    Unemployment_rate_2017  Median_Household_Income_2017  \
# 2                     3.9                       58343.0
# 3                     4.0                       56607.0
# 4                     5.9                       32490.0
# 5                     4.4                       45795.0
# 6                     4.0                       48253.0
#
#    Med_HH_Income_Percent_of_State_Total_2017
# 2                                      121.1
# 3                                      117.5
# 4                                       67.4
# 5                                       95.0
# 6                                      100.1
#
# [5 rows x 52 columns]

# %%
unemp[unemp['State']=='CA'].head()
# remove row 194
# Out:
#      FIPStxt State      County  Rural_urban_continuum_code_2013  \
# 194     6000    CA  California                              NaN
# 195     6001    CA    Alameda                               1.0
# 196     6003    CA     Alpine                               8.0
# 197     6005    CA     Amador                               6.0
# 198     6007    CA      Butte                               3.0
#
#      Urban_influence_code_2013  Metro_2013  Civilian_labor_force_2007  \
# 194                        NaN         NaN                 17893080.0
# 195                        1.0         1.0                   745198.0
# 196                        4.0         0.0                      493.0
# 197                        4.0         0.0                    17703.0
# 198                        2.0         1.0                   101228.0
#
#      Employed_2007  Unemployed_2007  Unemployment_rate_2007  \
# 194     16931590.0         961490.0                     5.4
# 195       710144.0          35054.0                     4.7
# 196          454.0             39.0                     7.9
# 197        16675.0           1028.0                     5.8
# 198        94489.0           6739.0                     6.7
#
#                        ...                      Civilian_labor_force_2016  \
# 194                    ...                                     19093658.0
# 195                    ...                                       837583.0
# 196                    ...                                          557.0
# 197                    ...                                        14574.0
# 198                    ...                                       101987.0
#
#      Employed_2016  Unemployed_2016  Unemployment_rate_2016  \
# 194     18048827.0        1044831.0                     5.5
# 195       801774.0          35809.0                     4.3
# 196          521.0             36.0                     6.5
# 197        13706.0            868.0                     6.0
# 198        95246.0           6741.0                     6.6
#
#      Civilian_labor_force_2017  Employed_2017  Unemployed_2017  \
# 194                 19311958.0     18393077.0         918881.0
# 195                   848335.0       817433.0          30902.0
# 196                      538.0          505.0             33.0
# 197                    14783.0        14059.0            724.0
# 198                   102982.0        97066.0           5916.0
#
#      Unemployment_rate_2017  Median_Household_Income_2017  \
# 194                     4.8                       71785.0
# 195                     3.6                       95550.0
# 196                     6.1                       55755.0
# 197                     4.9                       60588.0
# 198                     5.7                       48634.0
#
#      Med_HH_Income_Percent_of_State_Total_2017
# 194                                      100.0
# 195                                      133.1
# 196                                       77.7
# 197                                       84.4
# 198                                       67.7
#
# [5 rows x 52 columns]

# %%
unemp2 = unemp_l.drop(['FIPStxt','Rural_urban_continuum_code_2013','Urban_influence_code_2013','Metro_2013','Civilian_labor_force_2007','Employed_2007','Unemployed_2007','Civilian_labor_force_2008','Employed_2008','Unemployed_2008','Civilian_labor_force_2009','Employed_2009','Unemployed_2009','Civilian_labor_force_2010','Employed_2010','Unemployed_2010','Civilian_labor_force_2010','Employed_2010','Unemployed_2010','Civilian_labor_force_2011','Employed_2011','Unemployed_2011','Civilian_labor_force_2012','Employed_2012','Unemployed_2012','Civilian_labor_force_2013','Employed_2013','Unemployed_2013','Civilian_labor_force_2014','Employed_2014','Unemployed_2014','Civilian_labor_force_2015','Employed_2015','Unemployed_2015','Civilian_labor_force_2016','Employed_2016','Unemployed_2016','Civilian_labor_force_2017','Employed_2017','Unemployed_2017'],axis=1)
# ,'State'
# unemp_l
unemp2.head()
# Out:
#   State    County  Unemployment_rate_2007  Unemployment_rate_2008  \
# 2    AL  Autauga                      3.3                     5.1
# 3    AL  Baldwin                      3.1                     4.6
# 4    AL  Barbour                      6.3                     8.8
# 5    AL     Bibb                      4.1                     5.8
# 6    AL   Blount                      3.2                     4.7
#
#    Unemployment_rate_2009  Unemployment_rate_2010  Unemployment_rate_2011  \
# 2                     9.7                     8.9                     8.4
# 3                     9.8                    10.0                     9.0
# 4                    14.3                    12.3                    11.5
# 5                    13.3                    11.4                    10.5
# 6                    10.0                     9.8                     8.7
#
#    Unemployment_rate_2012  Unemployment_rate_2013  Unemployment_rate_2014  \
# 2                     6.9                     6.2                     5.8
# 3                     7.5                     6.6                     6.1
# 4                    11.5                    10.2                    10.5
# 5                     8.5                     7.9                     7.2
# 6                     6.9                     6.3                     6.1
#
#    Unemployment_rate_2015  Unemployment_rate_2016  Unemployment_rate_2017  \
# 2                     5.2                     5.1                     3.9
# 3                     5.5                     5.4                     4.0
# 4                     8.9                     8.4                     5.9
# 5                     6.6                     6.5                     4.4
# 6                     5.4                     5.4                     4.0
#
#    Median_Household_Income_2017  Med_HH_Income_Percent_of_State_Total_2017
# 2                       58343.0                                      121.1
# 3                       56607.0                                      117.5
# 4                       32490.0                                       67.4
# 5                       45795.0                                       95.0
# 6                       48253.0                                      100.1

# %%
unemp2.rename(columns={"State":"Postal"},inplace=True)

# %%
unemp2.drop(['Median_Household_Income_2017','Med_HH_Income_Percent_of_State_Total_2017'],axis=1).head()
# Out:
#   Postal    County  Unemployment_rate_2007  Unemployment_rate_2008  \
# 2     AL  Autauga                      3.3                     5.1
# 3     AL  Baldwin                      3.1                     4.6
# 4     AL  Barbour                      6.3                     8.8
# 5     AL     Bibb                      4.1                     5.8
# 6     AL   Blount                      3.2                     4.7
#
#    Unemployment_rate_2009  Unemployment_rate_2010  Unemployment_rate_2011  \
# 2                     9.7                     8.9                     8.4
# 3                     9.8                    10.0                     9.0
# 4                    14.3                    12.3                    11.5
# 5                    13.3                    11.4                    10.5
# 6                    10.0                     9.8                     8.7
#
#    Unemployment_rate_2012  Unemployment_rate_2013  Unemployment_rate_2014  \
# 2                     6.9                     6.2                     5.8
# 3                     7.5                     6.6                     6.1
# 4                    11.5                    10.2                    10.5
# 5                     8.5                     7.9                     7.2
# 6                     6.9                     6.3                     6.1
#
#    Unemployment_rate_2015  Unemployment_rate_2016  Unemployment_rate_2017
# 2                     5.2                     5.1                     3.9
# 3                     5.5                     5.4                     4.0
# 4                     8.9                     8.4                     5.9
# 5                     6.6                     6.5                     4.4
# 6                     5.4                     5.4                     4.0

# %%
unemp_ca = unemp2[unemp2['Postal'] == 'CA'].iloc[1:,:]
unemp_ca.head()
# Out:
#     Postal      County  Unemployment_rate_2007  Unemployment_rate_2008  \
# 195     CA    Alameda                      4.7                     6.2
# 196     CA     Alpine                      7.9                    10.5
# 197     CA     Amador                      5.8                     7.7
# 198     CA      Butte                      6.7                     8.5
# 199     CA  Calaveras                      6.4                     8.7
#
#      Unemployment_rate_2009  Unemployment_rate_2010  Unemployment_rate_2011  \
# 195                    10.3                    10.9                    10.1
# 196                    14.1                    12.9                    12.8
# 197                    11.4                    14.1                    13.6
# 198                    12.3                    13.9                    13.7
# 199                    13.6                    14.4                    14.0
#
#      Unemployment_rate_2012  Unemployment_rate_2013  Unemployment_rate_2014  \
# 195                     8.7                     7.2                     5.8
# 196                    11.2                     9.7                     8.2
# 197                    12.3                    10.3                     8.3
# 198                    12.2                    10.3                     8.6
# 199                    12.4                     9.9                     8.0
#
#      Unemployment_rate_2015  Unemployment_rate_2016  Unemployment_rate_2017  \
# 195                     4.7                     4.3                     3.6
# 196                     7.3                     6.5                     6.1
# 197                     6.6                     6.0                     4.9
# 198                     7.2                     6.6                     5.7
# 199                     6.4                     5.7                     4.7
#
#      Median_Household_Income_2017  Med_HH_Income_Percent_of_State_Total_2017
# 195                       95550.0                                      133.1
# 196                       55755.0                                       77.7
# 197                       60588.0                                       84.4
# 198                       48634.0                                       67.7
# 199                       58536.0                                       81.5

# %%
# unempca = unemp_ca.drop('Postal',axis=1)

# %%
unempca = pd.melt(unemp_ca,id_vars=['County','Postal'],var_name='Year',value_name='UnemploymentRate')
unempca.head()
# Out:
#        County Postal                    Year  UnemploymentRate
# 0    Alameda      CA  Unemployment_rate_2007               4.7
# 1     Alpine      CA  Unemployment_rate_2007               7.9
# 2     Amador      CA  Unemployment_rate_2007               5.8
# 3      Butte      CA  Unemployment_rate_2007               6.7
# 4  Calaveras      CA  Unemployment_rate_2007               6.4

# %%
# unempca['Year'] = unempca['Year'].apply(lambda x:x.unempca['Year'][0][-4:]
unempca['Year'] = unempca['Year'].str.strip().str[-4:]

# %%
# PROBLEM -- 
# unempca['Year'] = unempca['Year'].apply(lambda x:x.rsplit('_',maxsplit=-1)[2])
unempca['Year'].head()
# Out:
# 0    2007
# 1    2007
# 2    2007
# 3    2007
# 4    2007
# Name: Year, dtype: object

# %%
unempca.tail()
# Out:
#         County Postal  Year  UnemploymentRate
# 749    Tulare      CA  2017              64.6
# 750  Tuolumne      CA  2017              81.9
# 751   Ventura      CA  2017             114.8
# 752      Yolo      CA  2017              90.4
# 753      Yuba      CA  2017              75.0

# %%
#unempca['County'] = unempca['County'].str.strip(' ')
#unempca['County'].apply(lambda x: x.str.strip() if x == ' ' else x)
unempca['County'].str.strip(' ')
unempca.head(10)
# Out:
#           County Postal  Year  UnemploymentRate
# 0       Alameda      CA  2007               4.7
# 1        Alpine      CA  2007               7.9
# 2        Amador      CA  2007               5.8
# 3         Butte      CA  2007               6.7
# 4     Calaveras      CA  2007               6.4
# 5        Colusa      CA  2007              11.8
# 6  Contra Costa      CA  2007               4.7
# 7     Del Norte      CA  2007               7.5
# 8     El Dorado      CA  2007               5.2
# 9        Fresno      CA  2007               8.6

# %%
# unempca['Year'].astype(int).head()
# unempca['Year'] = pd.to_numeric(unempca['Year'], errors='coerce')
#unempca['Year'] = unempca['Year'].astype(int)
#unempca['Year'].head()
unempca[unempca['Year']=='Income'].head()
# Out:
#          County Postal    Year  UnemploymentRate
# 638    Alameda      CA  Income           95550.0
# 639     Alpine      CA  Income           55755.0
# 640     Amador      CA  Income           60588.0
# 641      Butte      CA  Income           48634.0
# 642  Calaveras      CA  Income           58536.0

# %%
unempca['County'].unique()
# Out:
# array(['Alameda ', 'Alpine ', 'Amador ', 'Butte ', 'Calaveras ',
#        'Colusa ', 'Contra Costa ', 'Del Norte ', 'El Dorado ', 'Fresno ',
#        'Glenn ', 'Humboldt ', 'Imperial ', 'Inyo ', 'Kern ', 'Kings ',
#        'Lake ', 'Lassen ', 'Los Angeles ', 'Madera ', 'Marin ',
#        'Mariposa ', 'Mendocino ', 'Merced ', 'Modoc ', 'Mono ',
#        'Monterey ', 'Napa ', 'Nevada ', 'Orange ', 'Placer ', 'Plumas ',
#        'Riverside ', 'Sacramento ', 'San Benito ', 'San Bernardino ',
#        'San Diego ', 'San Francisco ', 'San Joaquin ', 'San Luis Obispo ',
#        'San Mateo ', 'Santa Barbara ', 'Santa Clara ', 'Santa Cruz ',
#        'Shasta ', 'Sierra ', 'Siskiyou ', 'Solano ', 'Sonoma ',
#        'Stanislaus ', 'Sutter ', 'Tehama ', 'Trinity ', 'Tulare ',
#        'Tuolumne ', 'Ventura ', 'Yolo ', 'Yuba '], dtype=object)

# %%
unempca['County'].nunique()
# Out:
# 58

# %%
unempcaF = unempca.drop('Postal',axis=1)
unempcaF.head()
# WINNER!!!!!!!!!!!
# Out:
#        County    Year  UnemploymentRate
# 0    Alameda   2007.0               4.7
# 1     Alpine   2007.0               7.9
# 2     Amador   2007.0               5.8
# 3      Butte   2007.0               6.7
# 4  Calaveras   2007.0               6.4

# %%
groca.head()
# Out:
#         County Postal  Year GDPgrowth
# 186    Alameda     CA  2013       4.1
# 187     Alpine     CA  2013     -11.8
# 188     Amador     CA  2013       4.5
# 189      Butte     CA  2013       3.9
# 190  Calaveras     CA  2013       1.9

# %%
# unempca[unempca['County']=='Alameda']

# %%
gg= pd.merge(gdp_ca,groca,on=['County','Year','Postal'])
#gg[gg['County']=='Alameda'] -> works, three elements from 2013,2014,2015
gg.head()
# Out:
#       County Postal  Year       GDP GDPgrowth
# 0    Alameda     CA  2013  97646410       4.1
# 1     Alpine     CA  2013     80465     -11.8
# 2     Amador     CA  2013   1155937       4.5
# 3      Butte     CA  2013   6647096       3.9
# 4  Calaveras     CA  2013    786451       1.9

# %%
gg.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 174 entries, 0 to 173
# Data columns (total 5 columns):
# County       174 non-null object
# Postal       174 non-null object
# Year         174 non-null int32
# GDP          174 non-null object
# GDPgrowth    174 non-null object
# dtypes: int32(1), object(4)
# memory usage: 7.5+ KB

# %%
unempca['Year'] = unempca['Year'].astype(int)

# %%
unempca.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 754 entries, 0 to 753
# Data columns (total 4 columns):
# County              754 non-null object
# Postal              754 non-null object
# Year                754 non-null int32
# UnemploymentRate    754 non-null float64
# dtypes: float64(1), int32(1), object(2)
# memory usage: 20.7+ KB

# %%
unempca.head()
# Out:
#        County Postal  Year  UnemploymentRate
# 0    Alameda      CA  2007               4.7
# 1     Alpine      CA  2007               7.9
# 2     Amador      CA  2007               5.8
# 3      Butte      CA  2007               6.7
# 4  Calaveras      CA  2007               6.4

# %%
gg.head()
# Out:
#       County Postal  Year       GDP GDPgrowth
# 0    Alameda     CA  2013  97646410       4.1
# 1     Alpine     CA  2013     80465     -11.8
# 2     Amador     CA  2013   1155937       4.5
# 3      Butte     CA  2013   6647096       3.9
# 4  Calaveras     CA  2013    786451       1.9

# %%
ggu = pd.merge(gg,unempca,on=['County','Year','Postal'])
ggu.head()
# Out:
# Empty DataFrame
# Columns: [County, Postal, Year, GDP, GDPgrowth, UnemploymentRate]
# Index: []

# %%
ggud = pd.merge(ggu,disease,on=['County','Year'])
ggud

# %%
gg = gdpandgrowth.iloc[30:,:]

# %%
gg.head()
# Out:
#       County Postal  Year       GDP GDPgrowth
# 0    Alameda     CA  2013  97646410       4.1
# 1     Alpine     CA  2013     80465     -11.8
# 2     Amador     CA  2013   1155937       4.5
# 3      Butte     CA  2013   6647096       3.9
# 4  Calaveras     CA  2013    786451       1.9

# %%
gg.drop('Postal',axis=1).head()
# Out:
#       County  Year       GDP GDPgrowth
# 0    Alameda  2013  97646410       4.1
# 1     Alpine  2013     80465     -11.8
# 2     Amador  2013   1155937       4.5
# 3      Butte  2013   6647096       3.9
# 4  Calaveras  2013    786451       1.9

# %%
df = pd.merge(disease, gg, on=['Year','County'])
df.head()
# Out:
#                          Disease       County  Year     Sex  Count  \
# 0                      Amebiasis  Los Angeles  2014  Female     17
# 1                      Amebiasis  Los Angeles  2014   Total     73
# 2                      Amebiasis  Los Angeles  2014    Male     56
# 3  Anaplasmosis and Ehrlichiosis  Los Angeles  2014   Total      0
# 4  Anaplasmosis and Ehrlichiosis  Los Angeles  2014  Female      0
#
#    Population   Rate  CI. lower  CI.upper Unstable Postal        GDP GDPgrowth
# 0     5127242  0.332      0.193     0.531        *     CA  630438094         4
# 1    10124684  0.721      0.565     0.907      NaN     CA  630438094         4
# 2     4997442  1.121      0.846     1.455      NaN     CA  630438094         4
# 3    10124684  0.000      0.000     0.036        -     CA  630438094         4
# 4     5127242  0.000      0.000     0.072        -     CA  630438094         4

# %%
combined = pd.merge(df, unemp, on='County').drop(['CI. lower','CI.upper'],axis=1)

# %%
combined.head()

# %%
# str.contains()
# str.split()
# unemp['new_County'] = unemp['County'].str.split('/').str[0]

# %%
#unemp['new_County'] = unemp['County'].str.split(',')

# %%
 # unemp['very_new_County'] = unemp['new_County'].str.split(',').str[0]
# .str[0]???
