# %%
import pandas as pd
import numpy as np

# %%
disease = pd.read_csv('infectious_diseases.csv')

# %%
disease.head()
# Out:
#      Disease       County  Year     Sex  Count  Population   Rate  CI. lower  \
# 0  Amebiasis       Solano  2005   Total      0      410570  0.000      0.000
# 1  Amebiasis        Marin  2005    Male      4      121710  3.287      0.895
# 2  Amebiasis         Kern  2010  Female      1      404863  0.247      0.006
# 3  Amebiasis       Tulare  2001  Female      1      186935  0.535      0.014
# 4  Amebiasis  Los Angeles  2014  Female     17     5127242  0.332      0.193
#
#    CI.upper Unstable
# 0     0.898        -
# 1     8.415        *
# 2     1.376        *
# 3     2.980        *
# 4     0.531        *

# %%
type(disease['Year'])
# Out:
# pandas.core.series.Series

# %%
# disease[disease['County'].str.contains('Chambers')]
disease.sort_values('County').head()
# Out:
#                                                   Disease   County  Year  \
# 103455  Shiga Toxin Positive Feces (without culture co...  Alameda  2015
# 89171                                         Psittacosis  Alameda  2004
# 109309                        Spotted Fever Rickettsiosis  Alameda  2005
# 37862                          Cysticercosis or Taeniasis  Alameda  2005
# 32245   Creutzfeldt-Jakob Disease and other Transmissi...  Alameda  2009
#
#            Sex  Count  Population   Rate  CI. lower  CI.upper Unstable
# 103455   Total      2     1619679  0.123      0.015     0.446        *
# 89171   Female      0      746723  0.000      0.000     0.494        -
# 109309   Total      0     1459882  0.000      0.000     0.253        -
# 37862     Male      2      716004  0.279      0.034     1.009        *
# 32245    Total      1     1503827  0.066      0.002     0.370        *

# %%
gdp = pd.read_excel('gdp.xlsx',sheet_name='Real GDP')
# gdp data is all real gdp

# %%
gdp.rename(columns={"Countyname":"County", "Real Gross domestic product (GDP) by county":"2012", "Unnamed: 6":"2013", "Unnamed: 7":"2014", "Unnamed: 8":"2015"}, inplace=True)
gdp1 = gdp.loc[2:,:]
gdp1.head()
# Out:
#     FIPS   County Postal  LineCode                             IndustryName  \
# 2  01001  Autauga     AL       1.0                           All Industries
# 3  01001  Autauga     AL       2.0       Private goods-producing industries
# 4  01001  Autauga     AL       3.0    Private services-providing industries
# 5  01001  Autauga     AL       4.0    Government and government enterprises
# 6  01003  Baldwin     AL       1.0                           All Industries
#
#       2012     2013     2014     2015
# 2  1383941  1322416  1312668  1412939
# 3   286396   299115   310672   325250
# 4   948490   880098   861153   946148
# 5   149055   143062   140893   141294
# 6  5599194  6218819  6247887  5981958

# %%
# gdp_l = gdp1[gdp1['LineCode']==1.0]
#gdp_last = pd.melt(gdp_last, id_vars='County')
gdp1.drop(['FIPS','LineCode','IndustryName'],axis=1,inplace=True)
# drop ,'IndustryName','Postal' 
# removed: inplace=True
gdp1.head()
# Out:
#     County Postal     2012     2013     2014     2015
# 2  Autauga     AL  1383941  1322416  1312668  1412939
# 3  Autauga     AL   286396   299115   310672   325250
# 4  Autauga     AL   948490   880098   861153   946148
# 5  Autauga     AL   149055   143062   140893   141294
# 6  Baldwin     AL  5599194  6218819  6247887  5981958

# %%
gdp_last = pd.melt(gdp1,id_vars=['County','Postal'], var_name='Year', value_name='GDP')
gdp_last.head()
# Out:
#     County Postal  Year      GDP
# 0  Autauga     AL  2012  1383941
# 1  Autauga     AL  2012   286396
# 2  Autauga     AL  2012   948490
# 3  Autauga     AL  2012   149055
# 4  Baldwin     AL  2012  5599194

# %%
gdp_last[gdp_last['County']=='Baldwin'].head()
# Out:
#        County Postal  Year      GDP
# 4     Baldwin     AL  2012  5599194
# 5     Baldwin     AL  2012   681871
# 6     Baldwin     AL  2012  4306173
# 7     Baldwin     AL  2012   611151
# 1564  Baldwin     GA  2012  1106089

# %%
gdp_ca = gdp_last[gdp_last['Postal']=='CA']
gdp_ca.head()
# Out:
#       County Postal  Year       GDP
# 744  Alameda     CA  2012  93795276
# 745  Alameda     CA  2012  15313173
# 746  Alameda     CA  2012  66600579
# 747  Alameda     CA  2012  11881524
# 748   Alpine     CA  2012     91253

# %%
# gdpca = gdp_last.drop('Postal',axis=1,inplace=True)
gdp_last.drop('Postal',axis=1,inplace=True)

# %%
gdp_last.head()
# i didn't drop anything and yet it shows that i did
# Out:
#     County  Year      GDP
# 0  Autauga  2012  1383941
# 1  Autauga  2012   286396
# 2  Autauga  2012   948490
# 3  Autauga  2012   149055
# 4  Baldwin  2012  5599194

# %%
grow = pd.read_excel('gdp.xlsx',sheet_name='Real GDP Growth')

# %%
grow.rename(columns={"Countyname":"County","Real Gross domestic product (GDP) by county growth":"2013", "Unnamed: 6":"2014", "Unnamed: 7":"2015"}, inplace=True)
growth = grow.loc[2:,:]
#growth.head()
#growth[growth['Postal']=='LA'].iloc[250:300,:4]
#growth[growth['Postal']=='AK']
#.iloc[100:150,:4]
growth[growth['Postal']=='AL']
# keep 'All Industries'
growth1 = growth[growth['LineCode']==1.0]
growth1[growth1['County']=='Baldwin']
# Out:
#        FIPS   County Postal  LineCode    IndustryName  2013 2014 2015
# 6     01003  Baldwin     AL       1.0  All Industries  11.1  0.5 -4.3
# 1566  13009  Baldwin     GA       1.0  All Industries  -4.7    3 -2.2

# %%
growth1.drop(['FIPS','LineCode','IndustryName'],axis=1,inplace=True)
# drop ,'Postal'
growth1.head()
# Out:
#      County Postal  2013 2014  2015
# 2   Autauga     AL  -4.4 -0.7   7.6
# 6   Baldwin     AL  11.1  0.5  -4.3
# 10  Barbour     AL   7.5 -3.5   6.8
# 14     Bibb     AL   5.7 -2.8  -4.5
# 18   Blount     AL   8.1 -3.3  17.7

# %%
growthca = growth_ca.drop('Postal',axis=1,inplace=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-374-540859ce6fbe> in <module>
# ----> 1 growthca = growth_ca.drop('Postal',axis=1,inplace=True)
#
# ~\Anaconda3\lib\site-packages\pandas\core\frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3695                                            index=index, columns=columns,
#    3696                                            level=level, inplace=inplace,
# -> 3697                                            errors=errors)
#    3698
#    3699     @rewrite_axis_style_signature('mapper', [('copy', True),
#
# ~\Anaconda3\lib\site-packages\pandas\core\generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3109         for axis, labels in axes.items():
#    3110             if labels is not None:
# ...

# %%
growth_ca = pd.melt(growth1,id_vars=['County','Postal'],var_name='Year',value_name='GDPgrowth')
growth_ca.head()
# Out:
#     County Postal  Year GDPgrowth
# 0  Autauga     AL  2013      -4.4
# 1  Baldwin     AL  2013      11.1
# 2  Barbour     AL  2013       7.5
# 3     Bibb     AL  2013       5.7
# 4   Blount     AL  2013       8.1

# %%
growthca = growth_ca.drop('Postal',axis=1,inplace=True)
growthca.head()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-369-6642d5b6eb39> in <module>
# ----> 1 growthca = growth_ca.drop('Postal',axis=1,inplace=True)
#       2 growthca.head()
#
# ~\Anaconda3\lib\site-packages\pandas\core\frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3695                                            index=index, columns=columns,
#    3696                                            level=level, inplace=inplace,
# -> 3697                                            errors=errors)
#    3698
#    3699     @rewrite_axis_style_signature('mapper', [('copy', True),
#
# ~\Anaconda3\lib\site-packages\pandas\core\generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3109         for axis, labels in axes.items():
#    3110             if labels is not None:
# ...

# %%
growthca.head()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-368-469309e1437b> in <module>
# ----> 1 growthca.head()
#
# AttributeError: 'NoneType' object has no attribute 'head'

# %%
unemp = pd.read_excel('unemployment.xls',sheet_name='Unemployment Med HH Inc',skiprows=range(0,7))

# %%
unemp.rename(columns={"Area_name":"County"}, inplace=True)
#unemp.head()
unemp.iloc[69:102,:4].head()
# Out:
#     FIPStxt State                              County  \
# 69     2000    AK                              Alaska
# 70     2013    AK          Aleutians East Borough, AK
# 71     2016    AK      Aleutians West Census Area, AK
# 72     2020    AK  Anchorage Borough/municipality, AK
# 73     2050    AK              Bethel Census Area, AK
#
#     Rural_urban_continuum_code_2013
# 69                              NaN
# 70                              9.0
# 71                              9.0
# 72                              2.0
# 73                              7.0

# %%
unemp[unemp['County'].str.contains(',')].head()
# Out:
#    FIPStxt State              County  Rural_urban_continuum_code_2013  \
# 2     1001    AL  Autauga County, AL                              2.0
# 3     1003    AL  Baldwin County, AL                              3.0
# 4     1005    AL  Barbour County, AL                              6.0
# 5     1007    AL     Bibb County, AL                              1.0
# 6     1009    AL   Blount County, AL                              1.0
#
#    Urban_influence_code_2013  Metro_2013  Civilian_labor_force_2007  \
# 2                        2.0         1.0                    24383.0
# 3                        2.0         1.0                    82659.0
# 4                        6.0         0.0                    10334.0
# 5                        1.0         1.0                     8791.0
# 6                        1.0         1.0                    26629.0
#
#    Employed_2007  Unemployed_2007  Unemployment_rate_2007  \
# 2        23577.0            806.0                     3.3
# ...

# %%
unemp[unemp['County'].str.contains('/')].head()
# Out:
#      FIPStxt State                              County  \
# 72      2020    AK  Anchorage Borough/municipality, AK
# 80      2110    AK             Juneau Borough/city, AK
# 93      2220    AK              Sitka Borough/city, AK
# 98      2275    AK           Wrangell Borough/city, AK
# 100     2282    AK            Yakutat Borough/city, AK
#
#      Rural_urban_continuum_code_2013  Urban_influence_code_2013  Metro_2013  \
# 72                               2.0                        2.0         1.0
# 80                               5.0                        8.0         0.0
# 93                               7.0                       11.0         0.0
# 98                               9.0                       12.0         0.0
# 100                              9.0                       12.0         0.0
#
#      Civilian_labor_force_2007  Employed_2007  Unemployed_2007  \
# 72                    151051.0       143336.0           7715.0
# ...

# %%
unemp[unemp['County'].str.contains('County')].head()
# Out:
#    FIPStxt State              County  Rural_urban_continuum_code_2013  \
# 2     1001    AL  Autauga County, AL                              2.0
# 3     1003    AL  Baldwin County, AL                              3.0
# 4     1005    AL  Barbour County, AL                              6.0
# 5     1007    AL     Bibb County, AL                              1.0
# 6     1009    AL   Blount County, AL                              1.0
#
#    Urban_influence_code_2013  Metro_2013  Civilian_labor_force_2007  \
# 2                        2.0         1.0                    24383.0
# 3                        2.0         1.0                    82659.0
# 4                        6.0         0.0                    10334.0
# 5                        1.0         1.0                     8791.0
# 6                        1.0         1.0                    26629.0
#
#    Employed_2007  Unemployed_2007  Unemployment_rate_2007  \
# 2        23577.0            806.0                     3.3
# ...

# %%
unemp['County'] = unemp['County'].apply(lambda x:x.split(',')[0])
unemp.head()
# Out:
#    FIPStxt State          County  Rural_urban_continuum_code_2013  \
# 0        0    US   United States                              NaN
# 1     1000    AL         Alabama                              NaN
# 2     1001    AL  Autauga County                              2.0
# 3     1003    AL  Baldwin County                              3.0
# 4     1005    AL  Barbour County                              6.0
#
#    Urban_influence_code_2013  Metro_2013  Civilian_labor_force_2007  \
# 0                        NaN         NaN                152191093.0
# 1                        NaN         NaN                  2175612.0
# 2                        2.0         1.0                    24383.0
# 3                        2.0         1.0                    82659.0
# 4                        6.0         0.0                    10334.0
#
#    Employed_2007  Unemployed_2007  Unemployment_rate_2007  \
# 0    145156134.0        7034959.0                     4.6
# ...

# %%
unemp.iloc[:,10:30].head()
# Out:
#    Civilian_labor_force_2008  Employed_2008  Unemployed_2008  \
# 0                153761095.0    144860350.0        8900745.0
# 1                  2176489.0      2053477.0         123012.0
# 2                    24687.0        23420.0           1267.0
# 3                    83223.0        79372.0           3851.0
# 4                    10161.0         9267.0            894.0
#
#    Unemployment_rate_2008  Civilian_labor_force_2009  Employed_2009  \
# 0                     5.8                153825455.0    139594698.0
# 1                     5.7                  2162999.0      1924747.0
# 2                     5.1                    24703.0        22301.0
# 3                     4.6                    82451.0        74403.0
# 4                     8.8                    10003.0         8572.0
#
#    Unemployed_2009  Unemployment_rate_2009  Civilian_labor_force_2010  \
# 0       14230757.0                     9.3                154270492.0
# ...

# %%
unemp['County'] = unemp['County'].apply(lambda x:x.split('County')[0])
unemp.head()
# Out:
#    FIPStxt State         County  Rural_urban_continuum_code_2013  \
# 0        0    US  United States                              NaN
# 1     1000    AL        Alabama                              NaN
# 2     1001    AL       Autauga                               2.0
# 3     1003    AL       Baldwin                               3.0
# 4     1005    AL       Barbour                               6.0
#
#    Urban_influence_code_2013  Metro_2013  Civilian_labor_force_2007  \
# 0                        NaN         NaN                152191093.0
# 1                        NaN         NaN                  2175612.0
# 2                        2.0         1.0                    24383.0
# 3                        2.0         1.0                    82659.0
# 4                        6.0         0.0                    10334.0
#
#    Employed_2007  Unemployed_2007  Unemployment_rate_2007  \
# 0    145156134.0        7034959.0                     4.6
# ...

# %%
unemp[unemp['State'] != 'PR'].head()
# Out:
#    FIPStxt State         County  Rural_urban_continuum_code_2013  \
# 0        0    US  United States                              NaN
# 1     1000    AL        Alabama                              NaN
# 2     1001    AL       Autauga                               2.0
# 3     1003    AL       Baldwin                               3.0
# 4     1005    AL       Barbour                               6.0
#
#    Urban_influence_code_2013  Metro_2013  Civilian_labor_force_2007  \
# 0                        NaN         NaN                152191093.0
# 1                        NaN         NaN                  2175612.0
# 2                        2.0         1.0                    24383.0
# 3                        2.0         1.0                    82659.0
# 4                        6.0         0.0                    10334.0
#
#    Employed_2007  Unemployed_2007  Unemployment_rate_2007  \
# 0    145156134.0        7034959.0                     4.6
# ...

# %%
#unemp[unemp['County'].str.contains('/')]
unemp['County'] = unemp['County'].apply(lambda x:x.split('/')[0])
unemp_l = unemp.loc[2:,:]
unemp_l.head()
# Out:
#    FIPStxt State    County  Rural_urban_continuum_code_2013  \
# 2     1001    AL  Autauga                               2.0
# 3     1003    AL  Baldwin                               3.0
# 4     1005    AL  Barbour                               6.0
# 5     1007    AL     Bibb                               1.0
# 6     1009    AL   Blount                               1.0
#
#    Urban_influence_code_2013  Metro_2013  Civilian_labor_force_2007  \
# 2                        2.0         1.0                    24383.0
# 3                        2.0         1.0                    82659.0
# 4                        6.0         0.0                    10334.0
# 5                        1.0         1.0                     8791.0
# 6                        1.0         1.0                    26629.0
#
#    Employed_2007  Unemployed_2007  Unemployment_rate_2007  \
# 2        23577.0            806.0                     3.3
# 3        80099.0           2560.0                     3.1
# ...

# %%
unemp_l.drop(['FIPStxt','Rural_urban_continuum_code_2013','Urban_influence_code_2013','Metro_2013','Civilian_labor_force_2007','Employed_2007','Unemployed_2007','Civilian_labor_force_2008','Employed_2008','Unemployed_2008','Civilian_labor_force_2009','Employed_2009','Unemployed_2009','Civilian_labor_force_2010','Employed_2010','Unemployed_2010','Civilian_labor_force_2010','Employed_2010','Unemployed_2010','Civilian_labor_force_2011','Employed_2011','Unemployed_2011','Civilian_labor_force_2012','Employed_2012','Unemployed_2012','Civilian_labor_force_2013','Employed_2013','Unemployed_2013','Civilian_labor_force_2014','Employed_2014','Unemployed_2014','Civilian_labor_force_2015','Employed_2015','Unemployed_2015','Civilian_labor_force_2016','Employed_2016','Unemployed_2016','Civilian_labor_force_2017','Employed_2017','Unemployed_2017'],axis=1,inplace=True)
# ,'State'
# unemp_l

# %%
unemp_l.rename(columns={"State":"Postal"}, inplace=True)

# %%
unemp_l.drop(['Median_Household_Income_2017','Med_HH_Income_Percent_of_State_Total_2017'],axis=1,inplace=True)

# %%
unemp_l.head()
# Out:
#   Postal    County  Unemployment_rate_2007  Unemployment_rate_2008  \
# 2     AL  Autauga                      3.3                     5.1
# 3     AL  Baldwin                      3.1                     4.6
# 4     AL  Barbour                      6.3                     8.8
# 5     AL     Bibb                      4.1                     5.8
# 6     AL   Blount                      3.2                     4.7
#
#    Unemployment_rate_2009  Unemployment_rate_2010  Unemployment_rate_2011  \
# 2                     9.7                     8.9                     8.4
# 3                     9.8                    10.0                     9.0
# 4                    14.3                    12.3                    11.5
# 5                    13.3                    11.4                    10.5
# 6                    10.0                     9.8                     8.7
#
#    Unemployment_rate_2012  Unemployment_rate_2013  Unemployment_rate_2014  \
# ...

# %%
unemp_last = pd.melt(unemp_l,id_vars=['County','Postal'],var_name='Year',value_name='UnemploymentRate')
unemp_last.head()
# Out:
#      County Postal                    Year  UnemploymentRate
# 0  Autauga      AL  Unemployment_rate_2007               3.3
# 1  Baldwin      AL  Unemployment_rate_2007               3.1
# 2  Barbour      AL  Unemployment_rate_2007               6.3
# 3     Bibb      AL  Unemployment_rate_2007               4.1
# 4   Blount      AL  Unemployment_rate_2007               3.2

# %%
unemp_last['Year'] = unemp_last['Year'].apply(lambda x:x.split('_')[1])
unemp_last.head()
# Out:
#      County Postal  Year  UnemploymentRate
# 0  Autauga      AL  rate               3.3
# 1  Baldwin      AL  rate               3.1
# 2  Barbour      AL  rate               6.3
# 3     Bibb      AL  rate               4.1
# 4   Blount      AL  rate               3.2

# %%
type(unemp_last['Year'])
# Out:
# pandas.core.series.Series

# %%
gdp_last[gdp_last['County']=='Baldwin'].head()
# Out:
#        County  Year      GDP
# 4     Baldwin  2012  5599194
# 5     Baldwin  2012   681871
# 6     Baldwin  2012  4306173
# 7     Baldwin  2012   611151
# 1564  Baldwin  2012  1106089

# %%
growth_last[growth_last['County']=='Baldwin']
# Out:
#        County Postal  Year GDPgrowth
# 1     Baldwin     AL  2013      11.1
# 391   Baldwin     GA  2013      -4.7
# 3114  Baldwin     AL  2014       0.5
# 3504  Baldwin     GA  2014         3
# 6227  Baldwin     AL  2015      -4.3
# 6617  Baldwin     GA  2015      -2.2

# %%
gg= pd.merge(gdp_last,growth_last,on=['County','Year'])
gg.head()
# Out:
#     County  Year      GDP Postal GDPgrowth
# 0  Autauga  2013  1322416     AL      -4.4
# 1  Autauga  2013   299115     AL      -4.4
# 2  Autauga  2013   880098     AL      -4.4
# 3  Autauga  2013   143062     AL      -4.4
# 4  Baldwin  2013  6218819     AL      11.1

# %%
ggu = pd.merge(gg,unemp_last,on=['County'])
ggu.head()
# Out:
#        County Year_x     GDP Postal_x GDPgrowth Postal_y Year_y  \
# 0  Washington   2013  697845       AL       1.1       WA   rate
# 1  Washington   2013  697845       AL       1.1       WA   rate
# 2  Washington   2013  697845       AL       1.1       WA   rate
# 3  Washington   2013  697845       AL       1.1       WA   rate
# 4  Washington   2013  697845       AL       1.1       WA   rate
#
#    UnemploymentRate
# 0               4.7
# 1               5.4
# 2               9.2
# 3              10.0
# 4               9.3

# %%
ggud = pd.merge(ggu,disease,on=['County','Year'])
ggud
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-360-3347f4106f5a> in <module>
# ----> 1 ggud = pd.merge(ggu,disease,on=['County','Year'])
#       2 ggud
#
# ~\Anaconda3\lib\site-packages\pandas\core\reshape\merge.py in merge(left, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#      59                          right_index=right_index, sort=sort, suffixes=suffixes,
#      60                          copy=copy, indicator=indicator,
# ---> 61                          validate=validate)
#      62     return op.get_result()
#      63
#
# ~\Anaconda3\lib\site-packages\pandas\core\reshape\merge.py in __init__(self, left, right, how, on, left_on, right_on, axis, left_index, right_index, sort, suffixes, copy, indicator, validate)
#     549         (self.left_join_keys,
#     550          self.right_join_keys,
# ...

# %%
gg = gdpandgrowth.iloc[30:,:]

# %%
df = pd.merge(disease, gg, on='County')

# %%
combined = pd.merge(df, unemp, on='County').drop(['CI. lower','CI.upper'],axis=1)

# %%
combined.head()

# %%
# str.contains()
# str.split()
# unemp['new_County'] = unemp['County'].str.split('/').str[0]

# %%
#unemp['new_County'] = unemp['County'].str.split(',')

# %%
 # unemp['very_new_County'] = unemp['new_County'].str.split(',').str[0]
# .str[0]???
